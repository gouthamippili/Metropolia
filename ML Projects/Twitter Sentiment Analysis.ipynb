# %%
import pandas as pd
import numpy as np
import seaborn as srn
import matplotlib.pyplot as mtl


df=pd.read_csv('G:\\Python coding\\Metropolia\\ML Projects\\Dataset\\twitter.csv')
df.describe()
#df.describe(include=['object', 'category'])
# Out:
#                  id         label
# count  31962.000000  31962.000000
# mean   15981.500000      0.070146
# std     9226.778988      0.255397
# min        1.000000      0.000000
# 25%     7991.250000      0.000000
# 50%    15981.500000      0.000000
# 75%    23971.750000      0.000000
# max    31962.000000      1.000000

# %%
df=df.drop(['id'],axis=1)

# %%
df.head(3)

df['tweet'] [5]
# Out:
# '[2/2] huge fan fare and big talking before they leave. chaos and pay disputes when they get there. #allshowandnogo  '

# %%
df.hist(bins=30,figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'label'}>]], dtype=object)

# %%
srn.countplot(df['label'],label='Count')
# Out:
# <Axes: ylabel='count'>

# %%
srn.heatmap(df.isnull(),cbar=False,cmap="Blue",yticklabels=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 srn.heatmap(df.isnull(),cbar=False,cmap="Blue",yticklabels=False)
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
# ...

# %%
df['length']=df['tweet'].apply(len)

# %%
df.describe()

# %%
df[df['length']==84] ['tweet']

# %%
df['length'].hist(bins=30,figsize=(8,8))

# %%
positive= df[df['label']==0]

# %%
positive

# %%
sentence=positive['tweet'].tolist()

# %%
single_positive_sentence="".join(sentence)

# %%
#plot the sentence in wordcloud graph
from wordcloud import WordCloud

mtl.imshow(WordCloud().generate(single_positive_sentence))
mtl.figure(figsize=(10,10))

# %%
negetive=df[df['label']==1]

# %%
negetive

# %%
negetive_sentence=negetive['tweet'].tolist()

# %%
one_single_negetive_sentance="".join(negetive_sentence)

# %%
mtl.figure(figsize=(10,10))
mtl.imshow(WordCloud().generate(one_single_negetive_sentance))

# %%
# remove punctuation from the string

import string

string.punctuation
test= 'God please save me ....... !!!!!'

test_remove_punct= [ char for char in test   if  char not in  string.punctuation]
test_remove_punct = ''.join(test_remove_punct)
test_remove_punct

# %%
string.punctuation

# %%
#lets remove stop words- Perform cleaning of repeated words
import nltk
nltk.download('stopwords')   # Natural language tool kit

from nltk.corpus import stopwords
stopwords.words('english')

# %%
Test_word='I have a errie feeling today, not happy with what im undergoing, i have to get job asap!'

test_word_cleansed=[  word  for word in  Test_word.split()  if word.lower() not in  stopwords.words('english') ]

print(test_word_cleansed)

# %%
# Pratice excersise to remove Punctuation & stopwords in a sentence

Mini_Challange='Here is a mini-challenge, that will teach you how to remove stopwords and punctuations'

# Lets remove punctuations first
import string
string.punctuation

remove_punctuations=[  char  for char in Mini_Challange if char not in  string.punctuation ]

punctuations_removed=''.join(remove_punctuations)

punctuations_removed

# %%
# Lets remove stopwords
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stopwords.words('english')

remove_stopwords= [ word for word in punctuations_removed.split()  if word.lower() not in   stopwords.words('english')]
remove_stopwords

# %%
# Perform Tokenization
# i.e Convert words to 1,0

from sklearn.feature_extraction.text import CountVectorizer
sample_data=['This is the first paper.','This document is the second paper.','And this is the third one.','Is this the first paper?']

vectorizer=CountVectorizer()
X=vectorizer.fit_transform(sample_data)
print(vectorizer.get_feature_names_out())

print(X.toarray())

# %%
mini_challenge = ['Hello World','Hello Hello World','Hello World world world']

vector=CountVectorizer()
X=vector.fit_transform(mini_challenge)
X.toarray()

#print(vector.get_feature_names_out())

# %%
#CREATE A PIPELINE TO REMOVE PUNCTUATIONS, STOPWORDS AND PERFORM COUNT VECTORIZATION
import string
string. punctuation
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords.words('english')
def tweet_message(message):
    tweet_punctuation= [   char for char in message  if char not in string.punctuation]
    tweet_punctuation_join=''.join(tweet_punctuation)
    #print('88888888',tweet_punctuation_join)
    tweet_stopword_remove= [word for word in  tweet_punctuation_join.split()   if word.lower() not in stopwords.words('english')]
    print(tweet_stopword_remove)
    return tweet_stopword_remove


df['cleaned_tweet'] = df['tweet'].apply(tweet_message)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gkipp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['user', 'father', 'dysfunctional', 'selfish', 'drags', 'kids', 'dysfunction', 'run']
# ['user', 'user', 'thanks', 'lyft', 'credit', 'cant', 'use', 'cause', 'dont', 'offer', 'wheelchair', 'vans', 'pdx', 'disapointed', 'getthanked']
# ['bihday', 'majesty']
# ['model', 'love', 'u', 'take', 'u', 'time', 'urð\x9f\x93±', 'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91', 'ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦']
# ['factsguide', 'society', 'motivation']
# ['22', 'huge', 'fan', 'fare', 'big', 'talking', 'leave', 'chaos', 'pay', 'disputes', 'get', 'allshowandnogo']
# ['user', 'camping', 'tomorrow', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'dannyâ\x80¦']
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(dtype=np.uint8)

# Fit the vectorizer on the cleaned tweets
vectorizer.fit(df['cleaned_tweet'])

# Transform the cleaned tweets into feature vectors
transformed_data = vectorizer.transform(df['cleaned_tweet'])

# Convert transformed data to an array
vector_token_toarray = transformed_data.toarray()

# Print results
print("Feature Names:", vectorizer.get_feature_names_out())  # Vocabulary
print("Shape of Transformed Data:", vector_token_toarray.shape) 

X = pd.DataFrame(vector_token_toarray)
y = df['label']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 7
#       4 vectorizer = CountVectorizer(dtype=np.uint8)
#       6 # Fit the vectorizer on the cleaned tweets
# ----> 7 vectorizer.fit(df['cleaned_tweet'])
#       9 # Transform the cleaned tweets into feature vectors
#      10 transformed_data = vectorizer.transform(df['cleaned_tweet'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1340, in CountVectorizer.fit(self, raw_documents, y)
#    1324 def fit(self, raw_documents, y=None):
#    1325     """Learn a vocabulary dictionary of all tokens in the raw documents.
#    1326
#    1327     Parameters
#    (...)
#    1338         Fitted vectorizer.
#    1339     """
# -> 1340     self.fit_transform(raw_documents)
#    1341     return self
#
# ...

# %%
# Train the model using naive bayes model

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix

X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.80,random_state=100)
NBclassifier= MultinomialNB()
NBclassifier.fit(X_train,y_train)
y_predict_test = NB_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_predict_test)
sns.heatmap(cm, annot=True)

print(classification_report(y_test, y_predict_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       4 from sklearn.naive_bayes import MultinomialNB
#       5 from sklearn.metrics import classification_report, confusion_matrix
# ----> 7 X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.80,random_state=100)
#       8 NBclassifier= MultinomialNB()
#       9 NBclassifier.fit(X_train,y_train)
#
# NameError: name 'X' is not defined
